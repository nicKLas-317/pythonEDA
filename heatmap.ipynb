# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
print('libs loaded')
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 100)
sales = pd.read_csv('datas/house_pricing.csv');
sales.describe()
# Out:
# libs loaded
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726
# std       1.112799    30.202904     20.645407   181.066207   456.098091
# ...

# %%
sales
# Out:
#                date  date_block_num  shop_id  item_id  item_price  \
# 0        02.01.2013               0       59    22154      999.00
# 1        03.01.2013               0       25     2552      899.00
# 2        05.01.2013               0       25     2552      899.00
# 3        06.01.2013               0       25     2554     1709.05
# 4        15.01.2013               0       25     2555     1099.00
# ...             ...             ...      ...      ...         ...
# 2935844  10.10.2015              33       25     7409      299.00
# 2935845  09.10.2015              33       25     7460      299.00
# 2935846  14.10.2015              33       25     7459      349.00
# 2935847  22.10.2015              33       25     7440      299.00
# 2935848  03.10.2015              33       25     7460      299.00
#
#          item_cnt_day
# 0                 1.0
# 1                 1.0
# 2                -1.0
# 3                 1.0
# 4                 1.0
# ...               ...
# ...

# %%
# data = sales.drop(['date_block_num', 'shop_id', 'item_id', 'item_price', 'item_cnt_day'], axis=1)
# sales.corrwith(other=data, method='pearson')
# Out:
# date_block_num   NaN
# item_cnt_day     NaN
# item_id          NaN
# item_price       NaN
# shop_id          NaN
# dtype: float64

# %%
# Out:
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#            ..
# 2935844   NaN
# 2935845   NaN
# 2935846   NaN
# 2935847   NaN
# 2935848   NaN
# Length: 2935849, dtype: float64

# %%
sales.tail(15)
# Out:
#                date  date_block_num  shop_id  item_id  item_price  \
# 2935834  29.10.2015              33       25     7235       298.0
# 2935835  18.10.2015              33       25     7327       349.0
# 2935836  22.10.2015              33       25     7327       349.0
# 2935837  24.10.2015              33       25     7328       249.0
# 2935838  17.10.2015              33       25     7338       349.0
# 2935839  24.10.2015              33       25     7315       399.0
# 2935840  31.10.2015              33       25     7409       299.0
# 2935841  11.10.2015              33       25     7393       349.0
# 2935842  10.10.2015              33       25     7384       749.0
# 2935843  09.10.2015              33       25     7409       299.0
# 2935844  10.10.2015              33       25     7409       299.0
# 2935845  09.10.2015              33       25     7460       299.0
# 2935846  14.10.2015              33       25     7459       349.0
# ...

# %%
salesTail = sales.tail(15)
iloc[salesTail] 
# corr = salesTail.corrwith(salesTail, 0, method='pearson')
# corr
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-48d7addc35dd> in <module>
#       1 salesTail = sales.tail(15)
# ----> 2 iloc[salesTail]
#       3 # corr = salesTail.corrwith(salesTail, 0, method='pearson')
#       4 # corr
#
# NameError: name 'iloc' is not defined

# %%
#CORRECTION
# sales.column.to_list()[-15:]
sales.iloc[:,-15:]
# Out:
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 0              0           61              0          0            0
# 1            298            0              0          0            0
# 2              0           42              0          0            0
# 3              0           35            272          0            0
# 4            192           84              0          0            0
# ...          ...          ...            ...        ...          ...
# 1455           0           40              0          0            0
# 1456         349            0              0          0            0
# 1457           0           60              0          0            0
# 1458         366            0            112          0            0
# 1459         736           68              0          0            0
#
#       PoolArea PoolQC  Fence MiscFeature  MiscVal  MoSold  YrSold SaleType  \
# ...

# %%
sales.iloc[:,-15:].corr()
# Out:
#                WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# WoodDeckSF       1.000000     0.058661      -0.125989  -0.032771    -0.074181
# OpenPorchSF      0.058661     1.000000      -0.093079  -0.005842     0.074304
# EnclosedPorch   -0.125989    -0.093079       1.000000  -0.037305    -0.082864
# 3SsnPorch       -0.032771    -0.005842      -0.037305   1.000000    -0.031436
# ScreenPorch     -0.074181     0.074304      -0.082864  -0.031436     1.000000
# PoolArea         0.073378     0.060762       0.054203  -0.007992     0.051307
# MiscVal         -0.009551    -0.018584       0.018361   0.000354     0.031946
# MoSold           0.021011     0.071255      -0.028887   0.029474     0.023217
# YrSold           0.022270    -0.057619      -0.009916   0.018645     0.010694
# SalePrice        0.324413     0.315856      -0.128578   0.044584     0.111447
#
#                PoolArea   MiscVal    MoSold    YrSold  SalePrice
# ...

# %%
corr = sales.iloc[:,-15:].corr();

# %%
sns.heatmap(sales.iloc[:,-15:].corr())
# Out:
# <AxesSubplot:>

# %%
f, ax = plt.subplots(figsize=(20,5))
sns.heatmap(corr, annot=True, ax =ax)
# Out:
# <AxesSubplot:>
