# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
print('libs loaded')
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 100)
# Out:
# libs loaded

# %%
df = pd.read_csv('datas/IBM_HR_ATTRITION.csv'); df.info()
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# ...

# %%
sns.catplot(x='Attrition', y ="TotalWorkingYears", data=df, kind="box")

# %%
maskJob = df[df['TotalWorkingYears'] < 20]
maskJob
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
sns.catplot(x='Attrition', y ="TotalWorkingYears", data=maskJob, kind="box")

# %%
df.Attrition = df.Attrition.replace(to_replace = ["Yes", "No"], value=[1,0])
df.head()
# Out:
#    Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0   41          1      Travel_Rarely       1102                   Sales
# 1   49          0  Travel_Frequently        279  Research & Development
# 2   37          1      Travel_Rarely       1373  Research & Development
# 3   33          0  Travel_Frequently       1392  Research & Development
# 4   27          0      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
# ...

# %%
sns.lmplot(x="YearsAtCompany", y="Attrition", data= df, height=7)

# %%
sns.lmplot(x="DistanceFromHome", y="Attrition", data= df,  height=7)

# %%
df
# Out:
#       Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0      41          1      Travel_Rarely       1102                   Sales
# 1      49          0  Travel_Frequently        279  Research & Development
# 2      37          1      Travel_Rarely       1373  Research & Development
# 3      33          0  Travel_Frequently       1392  Research & Development
# 4      27          0      Travel_Rarely        591  Research & Development
# ...   ...        ...                ...        ...                     ...
# 1465   36          0  Travel_Frequently        884  Research & Development
# 1466   39          0      Travel_Rarely        613  Research & Development
# 1467   27          0      Travel_Rarely        155  Research & Development
# 1468   49          0  Travel_Frequently       1023                   Sales
# 1469   34          0      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
 logistic = True,

# %%
sns.lmplot(x="Age", y="Attrition", data= df,  height=7)

# %%
dfBis = pd.read_csv('datas/android_devices.csv'); 
dfBis.head()
# Out:
#   Retail Branding Marketing Name    Device                      Model
# 0             NaN            NaN    AD681H  Smartfren Andromax AD681H
# 1             NaN            NaN     FJL21                      FJL21
# 2             NaN            NaN       T31              Panasonic T31
# 3             NaN            NaN  hws7721g         MediaPad 7 Youth 2
# 4              3Q        OC1020A   OC1020A                    OC1020A

# %%
# dfBis['Toto'] = dfBis['Retail Branding']; 
dfBis = dfBis.rename(columns={'Retail Branding': 'TOto'})

# %%
dfBis
# Out:
#       Retail Branding Marketing Name       Device                      Model  \
# 0                 NaN            NaN       AD681H  Smartfren Andromax AD681H
# 1                 NaN            NaN        FJL21                      FJL21
# 2                 NaN            NaN          T31              Panasonic T31
# 3                 NaN            NaN     hws7721g         MediaPad 7 Youth 2
# 4                  3Q        OC1020A      OC1020A                    OC1020A
# ...               ...            ...          ...                        ...
# 14541           pendo    PNDPP44QC10  PNDPP44QC10                PNDPP44QC10
# 14542           pendo     PNDPP44QC7   PNDPP44QC7                 PNDPP44QC7
# 14543      sugar_aums         QPOINT        QPI-1                      QPI-1
# 14544       tecmobile       OmnisOne     OmnisOne                  Omnis One
# 14545           ucall          EASY1        EASY1                      EASY1
#
#              Toto
# 0             NaN
# ...

# %%
dfDevice = pd.read_csv('datas/user_device.csv'); 
search ="GT"
bool_series = dfDevice["device"].str.startswith(search, na = False)
dfDevice[bool_series]
# Out:
#      use_id  user_id platform  platform_version     device  use_type_id
# 5     22787    12921  android               4.3   GT-I9505            1
# 19    22801    10976  android               4.4   GT-I9505            1
# 20    22802    10976  android               4.4   GT-I9505            3
# 23    22805    29646  android               4.2   GT-I9195            1
# 49    22831     6541  android               4.1  GT-I8190N            1
# 89    22871    18883  android               4.3   GT-I9300            1
# 90    22872    18883  android               4.3   GT-I9300            3
# 93    22875    27593  android               5.0   GT-I9505            1
# 94    22876    27593  android               5.0   GT-I9505            1
# 98    22880    29366  android               5.0   GT-I9505            1
# 105   22887    29310  android               4.4   GT-I9195            1
# 106   22888    29668  android               5.0   GT-I9505            1
# ...

# %%
dfUsage= pd.read_csv('datas/user_usage.csv'); 
dfUsage['use_id'].str.startswith('GT')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-93-259dcab556ff> in <module>
#       1 dfUsage= pd.read_csv('datas/user_usage.csv');
# ----> 2 dfUsage['use_id'].str.startswith('GT')
#
# ~/workspace/AP-EEDSI/PythonEDA/virtenv/jupyterenvironment/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5459             or name in self._accessors
#    5460         ):
# -> 5461             return object.__getattribute__(self, name)
#    5462         else:
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# ~/workspace/AP-EEDSI/PythonEDA/virtenv/jupyterenvironment/lib/python3.8/site-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     178             # we're accessing the attribute of the class, i.e., Dataset.geo
#     179             return self._accessor
# ...

# %%
result = dfUsage.merge(dfDevice, left_on='use_id', right_on='use_id').drop(['platform_version', 'user_id', 'use_type_id'], axis=1)
result
# Out:
#      outgoing_mins_per_month  outgoing_sms_per_month  monthly_mb  use_id  \
# 0                      21.97                    4.82     1557.33   22787
# 1                    1710.08                  136.88     7267.55   22788
# 2                    1710.08                  136.88     7267.55   22789
# 3                      94.46                   35.17      519.12   22790
# 4                      71.59                   79.26     1557.33   22792
# ..                       ...                     ...         ...     ...
# 154                   198.59                   90.49     5191.12   23043
# 155                   198.59                   90.49     3114.67   23044
# 156                   106.65                   82.13     5191.12   23046
# 157                   344.53                   20.53      519.12   23049
# 158                    42.75                   46.83     5191.12   23053
#
#     platform                  device
# 0    android                GT-I9505
# ...

# %%
dfUsage.shape
# Out:
# (240, 4)

# %%
dfDevice.shape
# Out:
# (272, 6)

# %%
result.use_id.value_counts()
# Out:
# 23040    1
# 22967    1
# 22955    1
# 23046    1
# 22962    1
#         ..
# 22880    1
# 22881    1
# 22882    1
# 22883    1
# 23039    1
# Name: use_id, Length: 159, dtype: int64

# %%
dfUsage['use_id'].isin(dfDevice['use_id']).value_counts()
# Out:
# True     159
# False     81
# Name: use_id, dtype: int64

# %%
dfUsage.shape
result.shape
# Out:
# (159, 6)

# %%
# df.iloc[0:2]
result.sort_values(by=['device'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-87-183b403acdfa> in <module>
#       1 # df.iloc[0:2]
# ----> 2 result.sort_values(by=['device'])
#
# ~/workspace/AP-EEDSI/PythonEDA/virtenv/jupyterenvironment/lib/python3.8/site-packages/pandas/core/groupby/groupby.py in __getattr__(self, attr)
#     750             return self[attr]
#     751
# --> 752         raise AttributeError(
#     753             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     754         )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'sort_values'

# %%
result.iloc[0:2]
# Out:
#    outgoing_mins_per_month  outgoing_sms_per_month  monthly_mb  use_id  \
# 0                    21.97                    4.82     1557.33   22787
# 1                  1710.08                  136.88     7267.55   22788
#
#   platform    device
# 0  android  GT-I9505
# 1  android  SM-G930F

# %%
result.iloc[1:3,[0, 1 , 2, 3, 4, 5]]
# Out:
#    outgoing_mins_per_month  outgoing_sms_per_month  monthly_mb  use_id  \
# 1                  1710.08                  136.88     7267.55   22788
# 2                  1710.08                  136.88     7267.55   22789
#
#   platform    device
# 1  android  SM-G930F
# 2  android  SM-G930F

# %%
result.sort_values(by=['device'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-82-31a37a1af4f5> in <module>
# ----> 1 result.sort(by=['device'])
#
# TypeError: 'bool' object is not callable

# %%
result.describe()
# Out:
#                        outgoing_mins_per_month                           \
#                                          count         mean         std
# device
# A0001                                      2.0   170.395000  159.671782
# C6603                                      1.0    92.520000         NaN
# D2303                                      2.0    96.845000    3.372899
# D5503                                      2.0   146.450000    0.000000
# D5803                                      1.0   244.880000         NaN
# D6603                                      2.0   362.010000    0.000000
# E6653                                      1.0   135.090000         NaN
# EVA-L09                                    1.0   115.260000         NaN
# F3111                                      4.0    46.262500    6.465000
# GT-I8190N                                  1.0    85.970000         NaN
# GT-I9195                                   3.0   199.430000  188.567329
# ...

# %%
result

# %%
result.head()
# Out:
#      outgoing_mins_per_month  outgoing_sms_per_month  monthly_mb  use_id  \
# 0                      21.97                    4.82     1557.33   22787
# 1                    1710.08                  136.88     7267.55   22788
# 2                    1710.08                  136.88     7267.55   22789
# 3                      94.46                   35.17      519.12   22790
# 4                      71.59                   79.26     1557.33   22792
# ..                       ...                     ...         ...     ...
# 150                    57.66                   62.85     1557.33   23036
# 151                   180.18                   17.49     2076.45   23039
# 152                    12.85                   58.32       74.40   23040
# 156                   106.65                   82.13     5191.12   23046
# 158                    42.75                   46.83     5191.12   23053
#
#     platform                  device
# 0    android                GT-I9505
# ...

# %%
result
